# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Yigit\Desktop\env_uni\Codes\Fraud\creditcard.csv')

# %%
target = 'Class'

# %%
df.shape
# Out:
# (284807, 31)

# %%
df[target].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
ax = sns.boxplot(x=target, y="Time", data=df)

# %%
sns.displot(data=df, x="Time", hue=target)

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,fmt = ".2f",cbar=True)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.title('Correlation Map')
plt.show()

# %%
y = df[target]
X = df.drop(columns=[target])

# %%
sns.FacetGrid(df, hue = target, size = 6).map(sns.distplot, 'V17').add_legend()
# Out:
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue = target, size = 6).map(sns.distplot, 'V14').add_legend()
# Out:
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report# standardization

'''
scaler = StandardScaler()
scaler.fit(X_train)

X_train_data_lr = scaler.transform(X_train)
X_test_data_lr = scaler.transform(X_test)# logistic regression model
'''

lr = LogisticRegression(random_state = 21)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\n -------------Classification Report-------------\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9989291106351603
#
#  -------------Classification Report-------------
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.71      0.64      0.67        98
#
#     accuracy                           1.00     56962
#    macro avg       0.85      0.82      0.84     56962
# weighted avg       1.00      1.00      1.00     56962
# c:\Users\Yigit\Desktop\env_uni\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred = pd.Series(y_pred)

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 56962 entries, 159949 to 97767
# Series name: Class
# Non-Null Count  Dtype
# --------------  -----
# 56962 non-null  int64
# dtypes: int64(1)
# memory usage: 890.0 KB

# %%
y_pred.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 56962 entries, 0 to 56961
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 56962 non-null  int64
# dtypes: int64(1)
# memory usage: 445.1 KB

# %%
from sklearn.metrics import confusion_matrix

# %%
labels = [0, 1]
confusion_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(confusion_matrix, xticklabels=labels, yticklabels=labels, annot=True,linewidths = 0.1, fmt='d', cmap = 'YlGnBu')
plt.title('Confusion matrix without scaling', fontsize = 15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
y_test.shape, y_pred.shape
# Out:
# ((56962,), (56962,))

# %%
type(y_test), type(y_pred)
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)
